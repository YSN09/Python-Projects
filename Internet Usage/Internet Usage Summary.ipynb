# %% [markdown]
# # How Much of the World Has Access to the Internet?

# %% [markdown]
# To understand the state of the internet access across the world.

# %% [markdown]
# ### Task 1
# What are the top 5 countries with the highest internet use (by population share)?

# %% [markdown]
# ![image-2](image-2.png)
#
# We can see that in 2019, Bahrain had the highest internet use by populatiuon share. Which is closely followed by other Gulf countries such as Qatar, Kuwait and UAE.However the 5th highest by internet use is Denmark which is not a gulf country.

# %% [markdown]
# ### Task 2
# How many people had internet access in those countries in 2019?

# %% [markdown]
# The internet access among people across these countries are shown as below:
#
# ![image-4](image-4.png)

# %% [markdown]
# ### Task 3
# What are the top 5 countries with the highest internet use for each of the following regions: 'Middle East & North Africa', 'Latin America & Caribbean', 'East Asia & Pacific', 'South Asia', 'North America', 'Europe & Central Asia'?

# %% [markdown]
# _**Here internet_usage reflects the share of the entity's population who have used the internet in the last three months**_

# %% [markdown]
# ## Middle East and North Africa
#
# ![image-5](image-5.png)
#
# In the regions Middle East and North Africa, the gulf countries dominate in terms of the internet usage

# %% [markdown]
# ## Latin America And Caribbean
#
# ![image-7](image-7.png)
#
# In the Latin American and Caribbean region we can see that internet usage is the highest in Aruba followed by Bahamas, Chile,, Barbados and Cayman Islands

# %% [markdown]
# ## East Asia and Pacific
#
# ![image-8](image-8.png)
#
# In the East Asia and Pacific region the highest internet_usage is among South Korea which is then followed by Japan, New Zealand, Hong Kong and Australia

# %% [markdown]
# ## South Asia
#
# ![image-9](image-9.png)
#
# In South Asia, there is a considerable gap between the top 2, i.e., Iran and Maldives, as opposed to Sri Lanka, India, and Nepal, which have approximately half the internet usage of Iran and Maldives.

# %% [markdown]
# ## North America
#
# ![image-10](image-10.png)
#
# The top 4 countries are Bermuda with the highest followed by Canada , US and Greenland

# %% [markdown]
# ## Europe and Central Asia
#
# ![image-11](image-11.png)
#
# In Europe and Central Asia the internet_usage is the highest and the top 5 region are very closely seprated among themselves

# %% [markdown]
# ### Task 4
# Create a visualization for those five regions' internet usage over time

# %% [markdown]
# ![image-13](image-13.png)

# %% [markdown]
# ### Task 5
#
# What are the 5 countries with the most internet users?

# %% [markdown]
# ![image-14](image-14.png)
#
#
# The top 5 countries with the most user in 2019 are:
# 1. China
# 2. India
# 3. US
# 4. Brazil
# 5. Indonesia

# %% [markdown]
# ### Task 6
#
# What is the correlation between internet usage (population share) and broadband subscriptions for 2019?

# %% [markdown]
# ![image-15](image-15.png)
#
# We can see that there exists a positive correlation between Internet Usage and Broadband Subscriptions. Implying that when internet usage increases the broadband subscriptions also increase and vice versa.
