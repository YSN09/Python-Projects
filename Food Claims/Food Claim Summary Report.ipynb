# %% [markdown]
# # Food Claims

# %% [markdown]
# ## Task 1

# %% [markdown]
# For every column in the data:
# - State whether the values match the description given in the table above.
# - State the number of missing values in the column.
# - Describe what you did to make values match the description if they did not match

# %% [markdown]
# ## **_Solution_**
#
# The dataset food claims consist of 2000 Rows and 8 columns.
#
# **Claim_id**: This column contained values in the int64 format, implying that the values in this row were not nominal. The columns were then converted to a categorical format to satisfy the nominal condition. The column contained unique values and did not possess any null values.
#
# **time_to_close**: The column contained discrete values. All the values in the column are positive. There were 256 unique values ranging from 76 to 518. There were no missing values, so no changes were made to the column.
#
# **Claim_amount**: The column was in the object format.The column possesed values in the wrong format. The string value currency denomination was removed from the column and all the values in the column were converted to float and rounded to 2 digits. Therefore converting into a float format satisfied the continuous variable format. There were 2000 unique values and no null values.
#
# **amount_paid**: The column contained continuous values. The column comprises 1963 unique values ranging from 1516.72 to 52498.75. However, the column possessed 36 null values, later replaced with the median amount from the amount_paid column.
#
# **location**: The column possesses 4 unique values. The column satisfied the nominal variable condition. The column possessed no null values, so no changes were made.
#
# **individuals_on_claim**: The column contained discrete values. The column comprises 15 unique values ranging from 1 to 15. The minimum person is 1 in the column. There were no null values, so no changes were made to the column.
#
# **linked_cases**: The column contained nominal values. The column contained 26 null values, which were replaced with the 'False' value.
#
# **Cause**: The column contained nominal values. The column had 5 unique values as opposed to the 3 values. This was due to the wrong format of the letters. As 'meat' and 'Meat' were treated as separate values. All the mis-formated words were replaced and corrected. The column did not have any null values.

# %% [markdown]
# ## Task 2

# %% [markdown]
# Create a visualization that shows the number of claims in each location. Use the
# visualization to:
# - State which category of the variable location has the most observations
# - Explain whether the observations are balanced across categories of the variable location
#
# ## **_Solution_**
#
# ![image-9](image-9.png)
#
#
# Out of the 4 locations.The location "Recife" had the highest number of observation followed by "Sao Luis", "Fortazela" and "Natal"
#
# ![image-8](image-8.png)
#
# The observations across the categories were however unbalanced.With 44.2% of the observation consisting of Recife followed by Sao Luis with 25.9%.

# %% [markdown]
# ## Task 3

# %% [markdown]
# Describe the distribution of time to close for all claims. Your answer must include a
# visualization that shows the distribution.
#
# ## **_Solution_**
#
# ![image-5](image-5.png)
#
# The distribution of time to close for all claims are positively skewed implying that the mean of the time to close is greater than its median.Therefore signifying that most of the claims are closed quickly and only a select few claims take longer time to close

# %% [markdown]
# ## Task 4

# %% [markdown]
# Describe the relationship between time to close and location. Your answer must
# include a visualization to demonstrate the relationship.
#
# ## **_Solution_**
#
# ![image-10](image-10.png)
#
# The barplot shows that the average closing time across different regions is more or less the same. Implying mean closing time for all the regions are same.
#
# ![image-11](image-11.png)
#
# The violin plot shows that the minimum time to close the claims across the 4 regions is approximately the same.
# However, Sao Luis has the highest outlier indicating that Sao Luis, compared to other regions, has had instances where claims took significantly longer to close. This suggests that there may be unique factors or challenges in Sao Luis causing delays in the claims closure process. Fortaleza also experiences delays in closing claims. However, it has less extreme outliers than Sao Luis.
