# %% [markdown]
# Create a report that covers the following:
#
# What factors affect whether customers cancel their booking?
# Are cancellations more likely during weekends?
# Which general recommendations for the hotel can you make?

# %% [markdown]
# #### Task 1
# What factors affect whether customers cancel their booking?

# %% [markdown]
# When looking at factors involving customer cancellations. We have to look at all the possible reason:

# %% [markdown]
# ### Meal Plan
# Meal plan although may not be a important criteria for the cancellation of booking.But when we analyse the data we can see that:
#
# ![image](image.png)
#
# Significant proportion of the individuals that cancelled their booking had either opted for meal plan 1 or were defaulted to meal plan 1.
# If the default option is meal plan 1,then the customers should be given a choice to choose their own meal plan.

# %% [markdown]
# ### Car Parking Place
#
# ![image-2](image-2.png)
#
# We can see that inavailabilty of parking option doesn't result in cancellation of bookings.

# %% [markdown]
# ### Room Type Reserved
#
# ![image-3](image-3.png)
#
# Cancellation of reservation with hotel is more prominently associated with Room 1 i.e. customers who were reserved room 1 more often than not cancelled their reservation with the hotel.
# This may be asssociated with the room not living up to the expectations of the customers

# %% [markdown]
# ### Arrival Month
#
# ![image-4](image-4.png)
#
# From June to July we can see an increasing trend in the cancellation of reservation, peaking at the month of october.

# %% [markdown]
# ### Arrival Date
#
# ![image-5](image-5.png)
#
# We can see that majority of the cancellations either take place in the first or third week of the month

# %% [markdown]
# ### Market Segment Type
#
# ![image-6](image-6.png)
#
# We can see that majority of the customers who cancel their booking with the hotel are individuals who do their booking through offline modes. Closely following the offline segment is the corporate segment.

# %% [markdown]
# ### Repeat Customers
#
# ![image-7](image-7.png)
#
# An overwhelming majority of the time , guests who book with the hotel for the first time go through with the cancellation process.

# %% [markdown]
# ### No of previous cancellations
#
# ![image-8](image-8.png)
#
# The proportions of customers that did not cancel prior to the current booking far out weighs the individuals who cancelled prior to their current booking.

# %% [markdown]
# ### N.o of Previous bookings not cancelled
#
# ![image-9](image-9.png)
#
# People who book their reservation majority of the time did not have a history of cancellation.

# %% [markdown]
# ### Average Price of Room
#
# Since we are dealing with a binary data i.e. cancelled or not cancelled. We'll run a probit model regression to see if the average price of a room has any impact on the cancellation rates.
#
# ![image-10](image-10.png)
#
# The low Psuedo R-squ value along with the high LLR p-value shows us that the model is insignificant. Implying that customers cancellation does not depend on the average price of the room.

# %% [markdown]
# ## Task 2
# Are cancellations more likely during weekends?

# %% [markdown]
# ![image-11](image-11.png)
#
# Cancellation of Reservations are more likely during the weekdays as opposed to the weekends.

# %% [markdown]
# ### Suggestions
# The analysis shows that majority of the new customers that book through offline modes tend to cancel their booking. Inorder to prevent that hotel can charge higher intimation charges for the new guest taking into account the loss that could occur as a result of cancellation. Since Cancellations among the existing customers are less, therefore existing customers will be given benefits.Therefore motiviating the new guests to be a regular customer at the hotel.
#
# In order to prevent cancellation during the week days the company can run offers so as to attract customers and run the regular prices over the weekend.
